# %% [markdown]
# # JSON examples and exercise
# ****
# + get familiar with packages for dealing with JSON
# + study examples with JSON strings and files
# + work on exercise to be completed and submitted
# ****
# + reference: http://pandas-docs.github.io/pandas-docs-travis/io.html#json
# + data source: http://jsonstudio.com/resources/
# ****

# %%
import pandas as pd

# %% [markdown]
# ## imports for Python, Pandas

# %%
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## JSON example, with string
#
# + demonstrates creation of normalized dataframes (tables) from nested json string
# + source: http://pandas-docs.github.io/pandas-docs-travis/io.html#normalization

# %%
# define json string
data = [{'state': 'Florida', 
         'shortname': 'FL',
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
# use normalization to create tables from nested element
json_normalize(data, 'counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
# further populate tables created from nested element
json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %% [markdown]
# ****
# ## JSON example, with file
#
# + demonstrates reading in a json file as a string and as a table
# + uses small sample file containing data about projects funded by the World Bank
# + data source: http://jsonstudio.com/resources/

# %%
# load as Pandas dataframe
sample_json_df = pd.read_json('C://Users//J Doug//Desktop//Ethiopia//data_wrangling_json//data//world_bank_projects_less.json')
sample_json_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ffed8e89bdb3> in <module>
#       1 # load as Pandas dataframe
# ----> 2 sample_json_df = pd.read_json('C://Users//J Doug//Desktop//Ethiopia//data_wrangling_json//data//world_bank_projects_less.json')
#       3 sample_json_df
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/json/json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
# ...

# %% [markdown]
# ****
# ## JSON exercise
#
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
import json
from pandas.io.json import json_normalize
from collections import Counter
from collections import defaultdict
import pandas as pd
import numpy as np

# %%
project = pd.read_json('/Users/justin/projects/data_wrangling_json/data/world_bank_projects.json')
project.head()
# Out:
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
# 2  {'$oid': '52b213b38594d8a2be17c782'}        2014             November
# 3  {'$oid': '52b213b38594d8a2be17c783'}        2014              October
# 4  {'$oid': '52b213b38594d8a2be17c784'}        2014              October
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
# 2  2013-11-01T00:00:00Z   MINISTRY OF FINANCE AND ECONOMIC DEVEL
# 3  2013-10-31T00:00:00Z   MIN. OF PLANNING AND INT'L COOPERATION
# 4  2013-10-31T00:00:00Z                      MINISTRY OF FINANCE
#
#             closingdate                              country_namecode  \
# ...

# %%
# For finding the 10 countries with most projects, first extract the column: "countryname" from DataFrame, 
# then use value_counts and head(10) to get the answer

country_count = project["countryname"].value_counts()
print(country_count.head(10))
# Out:
# Republic of Indonesia              19
# People's Republic of China         19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# People's Republic of Bangladesh    12
# Nepal                              12
# Kingdom of Morocco                 12
# Republic of Mozambique             11
# Africa                             11
# Name: countryname, dtype: int64

# %%
# Find the top 10 major project themes (using column 'mjtheme_namecode'), for getting the result, applying same method as above

themes_count = project["mjtheme_namecode"].value_counts()
print(themes_count.head(10))
# Out:
# [{'code': '11', 'name': 'Environment and natural resources management'}, {'code': '11', 'name': 'Environment and natural resources management'}]                                                                                12
# [{'code': '8', 'name': 'Human development'}, {'code': '11', 'name': ''}]                                                                                                                                                        11
# [{'code': '8', 'name': 'Human development'}, {'code': '8', 'name': 'Human development'}]                                                                                                                                         8
# [{'code': '4', 'name': 'Financial and private sector development'}, {'code': '4', 'name': 'Financial and private sector development'}]                                                                                           6
# ...

# %%
# I notice some " " for the result of question 2, now going to fill in the missing data 
# To be sure about what value to filled in the missing data, I am going to first print out the "mjtheme_namecode" column 

print(project["mjtheme_namecode"]["code"])

# Did not work becoz its dictionary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d33b9d300fc5> in <module>
#       2 # To be sure about what value to filled in the missing data, I am going to first print out the "mjtheme_namecode" column
#       3
# ----> 4 print(project["mjtheme_namecode"]["code"])
#       5
#       6 # Did not work becoz its dictionary
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# ...

# %%
# From the error generated above, the method is not pd friendly, so have to use another way to import the data
datas = json.load((open("/Users/justin/projects/data_wrangling_json/data/world_bank_projects.json")))

# %%
df = json_normalize(datas, 'mjtheme_namecode')
# Normalize, turn each keys into column
print(df.head())
# Out:
#   code                                   name
# 0    8                      Human development
# 1   11
# 2    1                    Economic management
# 3    6  Social protection and risk management
# 4    5                  Trade and integration

# %%
# Now going to sort the df with code, and ffill the blank
df_sort = df.sort_values("code")
print(df_sort.head(20))
df_replaced = df_sort["name"].replace(to_replace = "", value = np.nan)
print(df_replaced.fillna(method = "ffill"))

# I have to replace df['column_name'].replace(to replace the empty string)
# pandas. nafill(ffill)
# nan cannot be a string, need to be a numpy array, problem solved!!
# Out:
#      code                 name
# 458     1  Economic management
# 1235    1  Economic management
# 1230    1  Economic management
# 1229    1  Economic management
# 1218    1  Economic management
# 900     1  Economic management
# 648     1  Economic management
# 647     1  Economic management
# 1078    1  Economic management
# 1206    1  Economic management
# 1437    1
# 357     1  Economic management
# 363     1
# 1010    1  Economic management
# 784     1  Economic management
# 1024    1
# 88      1  Economic management
# 1045    1  Economic management
# 497     1  Economic management
# 1056    1  Economic management
# 458     Economic management
# 1235    Economic management
# 1230    Economic management
# 1229    Economic management
# 1218    Economic management
# 900     Economic management
# 648     Economic management
# 647     Economic management
# 1078    Economic management
# 1206    Economic management
# 1437    Economic management
# 357     Economic management
# ...
